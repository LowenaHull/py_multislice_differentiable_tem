# %% [markdown]
# # Work starting on January 19th: Part 2

# %% [markdown]
# 1. Just have the defocus (and no aberration) <br>
#     a. How does the performance vary with number of iterations? <br>
#     b. How does the performance vary with learning rate? <br>
#     c. How does the performance vary with loss multiplier? <br>
#     d. How does the performance vary with optimizer?
#         i. Research what SGD and Adam optimizers are.
#         ii. What are the benefits of Adam over SGD? In what cases are which more or less appropriate?
#     e. How does the performance vary with different starting values of defocus? <br>
#         i. Research what is typical uncertainty in the defocus value.
#
# 2. Just take one aberration (spherical aberration) into account. Repeat above steps. <br>
#    Also track what happens to the aberration values- should tend towards the GT (0).
#    a. Different aberration values- use the best value from this to influence the choice of starting value for future    programs <br>
#    b. Number of iterations
#    c. Learning rate
#    d. Loss multiplier (worth repeating?)
#
# 3. Add some noise to the reference image. <br>
#     Generate image and add noise using the Demos/HRTEM.py program.
#
# 4. Simulate a molecule instead of a crystal. <br>
#
# While examining, collect the resultant images.
#
# While examining, look at the gradients.
# The gradient if starting at a defocus of 200 (the ground truth) should be zero.

# %%
import pyms
import numpy as np
import torch
import time
from pyms.Probe import aberration
from copy import deepcopy
import matplotlib.pyplot as plt

from pyms.utils.torch_utils import (
    amplitude,
    crop_to_bandwidth_limit_torch,
    size_of_bandwidth_limited_array,
    amplitude,
)

from pyms.Probe import (
    make_contrast_transfer_function,
)

# %matplotlib inline

#crystal = pyms.structure.fromfile(
#    "Structures/SrTiO3_CeO2_interface.xyz", atomic_coordinates="cartesian"
#)

crystal = pyms.structure.fromfile(
    "/home/hremadmin/py_multislice_differentiable/py_multislice_differentiable_tem/Demos/Structures/SrTiO3_CeO2_interface.xyz", atomic_coordinates="cartesian"
)

# A few maniupulations to remove vaccuum at edges and create a psuedo-periodic structure
crystal = crystal.resize([0.1, 0.76], axis=0)

other = deepcopy(crystal).resize([0.017, 0.99], axis=0)
other.reflect([0])
crystal = crystal.concatenate(other, axis=0)

# Subslicing of crystal for multislice
subslices = [0.33, 0.66, 1.0]

# Grid size in pixels
gridshape = [1024, 1024]

# Tile structure in multislice for a square grid
tiling = [1, 7]

# Probe accelerating voltage in eV
eV = 3e5

# Objective aperture in mrad
app = 15

# No aperture is also an option
# app = None

# Set up series of thicknesses
thicknesses = np.array([100])

# %%
# Establish aberrations
# Introduce one aberration: the spherical aberration

def establish_aberrations(ab_value):
    """Create a list of aberrations. Initialise with starting values."""

    aberrations = []

    # Initial guesses for aberrations
    df = 175.0
    Cs = ab_value
    
    # Krivanek aberration coefficient, Haider aberration coefficient, colloquial name, amplitude, angle, n, m
    # n and m are constants (shouldn't be differentiable), amplitude and angle should be

    aberrations.append(aberration("C10", "C1", "Defocus          ", torch.tensor([df], requires_grad = True), 0.0, 1, 0.0))
    aberrations.append(aberration("C30", "C3", "3rd order spher. ", torch.tensor([Cs], requires_grad = True), 0.0, 3, 0.0))
    
    return aberrations

# %%
# Set up our initial guess for the crystal HRTEM
# It uses the aberrations (including defocus) as set above

def create_initial_guess(aberrations):

    output = pyms.HRTEM(
        crystal,
        gridshape,
        eV,
        app,
        thicknesses,
        subslices=subslices,
        aberrations=aberrations,
        df= aberrations[0].amplitude,
        tiling=tiling,
        nfph=1,
        showProgress='notebook', 
        apply_ctf = False,
    )
    #plt.imshow(torch.abs(output).detach().cpu().numpy(), vmax = 10)
    
    return output

# %%
def save_sim_image(sim_image, ab_value):
    plt.imshow(sim_image[0].detach().cpu().numpy())

    plt.title(u'Simulated image of SrTiO\u2083\n with initial spherical aberration of {value}\n and defocus of 175.0'.format(value=ab_value), fontsize=15)
    plt.xticks([])
    plt.yticks([])

    filepath = "/home/hremadmin/Documents/Project/ML_files/Work_Jan_19/Part_2_multiple_aberrations/Variation_with_initial_ab_value/simulated_image_"+ str(ab_value) + ".jpg"
    plt.savefig(filepath, dpi=500)
    print("Saved")

# %%
def optimise(aberrations, output, ref_data, n_iters, learning_rate, loss_multiplier, ab_value):
    """Go through and refine the aberrations to minimise difference between initial guess (output) and experimental image"""

    bw_limit_size = size_of_bandwidth_limited_array(gridshape)
    rsize = np.asarray(crystal.unitcell[:2]) * np.asarray(tiling)

    curves = []
    params = []

    for i in range(0, len(aberrations)):
        params.append(aberrations[i].amplitude)
        curves.append([])

    optimizer = torch.optim.Adam(params, lr = learning_rate)
    criterion = torch.nn.MSELoss()

    loss_curve = []


    start = time.time()

    for iter in range(n_iters):
        ctf = (
                torch.stack(
                    [
                        make_contrast_transfer_function(
                            bw_limit_size, rsize, eV, app, df=aberrations[0].amplitude, aberrations=aberrations
                        )
                    ]
                )
            .type(torch.complex128)
            .to('cpu') # changed cuda to cpu
        )

        sim_image = amplitude(torch.fft.ifftn(ctf * output, dim=(-2, -1)))

        optimizer.zero_grad()

        loss = criterion(sim_image, ref_data)*loss_multiplier

        loss.backward()

        optimizer.step()

        loss_curve.append(loss.item())


        for i in range(0,len(curves)):
            curves[i].append(aberrations[i].amplitude.item())


    end = time.time()
    
    runtime = end-start
    
    save_sim_image(sim_image, ab_value)
    
    print(ab_value)
    print("\n")
    print(aberrations[1].amplitude.grad)
    
    return runtime, loss.item(), aberrations[0].amplitude.item(), aberrations[1].amplitude.item()

# %%
def main(n_iters, learning_rate, loss_multiplier, ab_value):
    aberrations = establish_aberrations(ab_value)
    output = create_initial_guess(aberrations)
    
    # Load in "experimental" data
    path = '/home/hremadmin/Documents/Project/differentiable/df_200_test_data.npy'
    ref_data = np.load(path)
    ref_data = torch.tensor(ref_data).to('cpu')
    
    runtime, loss, defocus_final, ab_final = optimise(aberrations, output, ref_data, n_iters, learning_rate, loss_multiplier, ab_value)
    return runtime, loss, defocus_final, ab_final

# %%
initial_ab = [-10.0, -5.0, 0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 35.0, 50.0]

# Constants
learning_rate = 1e-1
loss_multiplier = 1e9
n_iterations = 2000

runtimes = []
losses = []
defocus_values = []
ab_values = []

for i in initial_ab:
    runtime, loss, defocus_final, ab_final = main(n_iterations, learning_rate, loss_multiplier, i)
    runtimes.append(runtime)
    losses.append(loss)
    defocus_values.append(defocus_final)
    ab_values.append(ab_final)
# Out:
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# -10.0
#
#
# tensor([-1.0868e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# -5.0
#
#
# tensor([1.8669e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 0.0
#
#
# tensor([2.1901e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 5.0
#
#
# tensor([-2.6861e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 10.0
#
#
# tensor([-4.4388e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 15.0
#
#
# tensor([-8.7540e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 20.0
#
#
# tensor([-1.2894e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 25.0
#
#
# tensor([1.0985e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 35.0
#
#
# tensor([2.3824e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 50.0
#
#
# tensor([-1.0783e-11])

# %%
# Saving data to file code

filename = "Variation_initial_aberration.txt"

f = open(filename, "w")
x = "Initial Aberration Value, Final Aberration Value, Loss, Final defocus value, Time to run"
f.write(x)
f.write("\n")

for i in range(0, len(initial_ab)):
    line = str(initial_ab[i]) +  ", " + str(ab_values[i]) + ", "+ str(losses[i]) + ", " + str(defocus_values[i]) + ", " + str(runtimes[i])
    f.write(line)
    f.write("\n")

f.close()

# %%
plt.plot(initial_ab, losses)
plt.ylabel('Loss')
plt.xlabel('Initial Cs value')

filepath = "/home/hremadmin/Documents/Project/ML_files/Work_Jan_19/Part_2_multiple_aberrations/Variation_with_initial_ab_value/Loss.jpg"
plt.savefig(filepath, dpi=500)

plt.show()

# %%
plt.plot(initial_ab, defocus_values)
plt.ylabel('Final defocus value')
plt.xlabel('Initial Cs value')

filepath = "/home/hremadmin/Documents/Project/ML_files/Work_Jan_19/Part_2_multiple_aberrations/Variation_with_initial_ab_value/Defocus.jpg"
plt.savefig(filepath, dpi=500)

plt.show()

# %%
plt.plot(initial_ab, ab_values)
plt.ylabel('Final Cs value')
plt.xlabel('Initial Cs value')

filepath = "/home/hremadmin/Documents/Project/ML_files/Work_Jan_19/Part_2_multiple_aberrations/Variation_with_initial_ab_value/Aberration.jpg"
plt.savefig(filepath, dpi=500)

plt.show()

# %%
# ahhhhh forgot to add to the things to be differentiated
# no I have???
# Why are they exactly correlated

for i in range(len(ab_values)):
    print(ab_values[i] - initial_ab[i])
    
# So there are some small differences, but the values really aren't changing a lot

# Is it because the learning rate is so small?
# Out:
# 2.304203987121582
# 1.7026996612548828
# 1.6005091667175293
# 2.354933738708496
# 2.256694793701172
# 2.2033023834228516
# 2.1070518493652344
# 1.8989601135253906
# 1.7284393310546875
# 2.0277748107910156

# %%
# try again with a larger learning rate?

initial_ab = [-10.0, -5.0, 0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 35.0, 50.0]

# Constants
learning_rate = 1e1 # 100x bigger
loss_multiplier = 1e9
n_iterations = 2000

runtimes_2 = []
losses_2 = []
defocus_values_2 = []
ab_values_2 = []

for i in initial_ab:
    runtime, loss, defocus_final, ab_final = main(n_iterations, learning_rate, loss_multiplier, i)
    runtimes_2.append(runtime)
    losses_2.append(loss)
    defocus_values_2.append(defocus_final)
    ab_values_2.append(ab_final)

plt.plot(initial_ab, ab_values_2)
plt.ylabel('Final Cs value')
plt.xlabel('Initial Cs value')


plt.show()
# Out:
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# -10.0
#
#
# tensor([1.5230e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# -5.0
#
#
# tensor([-1.9751e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 0.0
#
#
# tensor([3.4796e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 5.0
#
#
# tensor([3.1677e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 10.0
#
#
# tensor([-2.8563e-13])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 15.0
#
#
# tensor([3.1076e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 20.0
#
#
# tensor([-1.5989e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 25.0
#
#
# tensor([-1.0727e-11])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 35.0
#
#
# tensor([-3.2574e-12])
# Lowena-modified code
# True
# Making projected potentials:   0%|          | 0/5 [00:00<?, ?it/s]
# 2
# Frozen phonon iteration:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved
# 50.0
#
#
# tensor([1.5975e-11])

# %%
plt.plot(initial_ab, ab_values_2)
plt.ylabel('Final Cs value')
plt.xlabel('Initial Cs value')


plt.show()

# %%
# Well at least its no longer linear?

# %%
# Deviation from GT value
y_data = [ab_values_2[i] - initial_ab[i] for i in range(0, len(initial_ab))]

plt.plot(initial_ab, y_data)
plt.ylabel('Change in Cs value')
plt.xlabel('Initial Cs value')


plt.show()

# %%
print(y_data[2])
# so the Cs goes to -4 from 0 (GT)
# Out:
# -3.9863288402557373

# %%
# Interesting that for an initial value of 0 for the Cs (i.e, the ground truth!) 
# there was still a change in Cs value when there shouldn've been none.
